# %% [markdown]
# #### PARTIE 1 - IMPORTS ET CHARGEMENT DES DONNÉES

# %%
import os
import re
import random
import pandas as pd
from textblob import TextBlob
import spacy
from nltk.corpus import wordnet
import nltk
nltk.download('wordnet')
nltk.download('omw-1.4')

# %%
# Charger les datasets
train = pd.read_csv("../data/raw/train.csv")
test = pd.read_csv("../data/raw/test.csv")

print("Train shape:", train.shape)
print("Test shape:", test.shape)
train.head()

# %%
# Afficher les catégories et leur nombre
categories = train['category'].unique()
print("Nombre d'intentions :", len(categories))
print("Intents:", categories)
# Out:
# Nombre d'intentions : 77
# ['card_arrival' 'card_linking' 'exchange_rate'
#  'card_payment_wrong_exchange_rate' 'extra_charge_on_statement'
#  'pending_cash_withdrawal' 'fiat_currency_support'
#  'card_delivery_estimate' 'automatic_top_up' 'card_not_working'
#  'exchange_via_app' 'lost_or_stolen_card' 'age_limit' 'pin_blocked'
#  'contactless_not_working' 'top_up_by_bank_transfer_charge'
#  'pending_top_up' 'cancel_transfer' 'top_up_limits'
#  'wrong_amount_of_cash_received' 'card_payment_fee_charged'
#  'transfer_not_received_by_recipient' 'supported_cards_and_currencies'
#  'getting_virtual_card' 'card_acceptance' 'top_up_reverted'
#  'balance_not_updated_after_cheque_or_cash_deposit'
#  'card_payment_not_recognised' 'edit_personal_details'
#  'why_verify_identity' 'unable_to_verify_identity' 'get_physical_card'
#  'visa_or_mastercard' 'topping_up_by_card' 'disposable_card_limits'
#  'compromised_card' 'atm_support' 'direct_debit_payment_not_recognised'
#  'passcode_forgotten' 'declined_cash_withdrawal' 'pending_card_payment'
#  'lost_or_stolen_phone' 'request_refund' 'declined_transfer'
#  'Refund_not_showing_up' 'declined_card_payment' 'pending_transfer'
#  'terminate_account' 'card_swallowed' 'transaction_charged_twice'
#  'verify_source_of_funds' 'transfer_timing' 'reverted_card_payment?'
#  'change_pin' 'beneficiary_not_allowed' 'transfer_fee_charged'
#  'receiving_money' 'failed_transfer' 'transfer_into_account'
#  'verify_top_up' 'getting_spare_card' 'top_up_by_cash_or_cheque'
#  'order_physical_card' 'virtual_card_not_working'
#  'wrong_exchange_rate_for_cash_withdrawal' 'get_disposable_virtual_card'
#  'top_up_failed' 'balance_not_updated_after_bank_transfer'
#  'cash_withdrawal_not_recognised' 'exchange_charge'
#  'top_up_by_card_charge' 'activate_my_card' 'cash_withdrawal_charge'
#  'card_about_to_expire' 'apple_pay_or_google_pay' 'verify_my_identity'
#  'country_support']

# %%
# Distribution initiale des catégories
print("\nDistribution initiale des catégories dans TRAIN :")
train_counts = train['category'].value_counts().reset_index()
train_counts.columns = ['category', 'Count']
print(train_counts)
# Out:
# 🔍 Distribution of categories in TRAIN set:
#                                             category  Count
# 0                           card_payment_fee_charged    187
# 1                direct_debit_payment_not_recognised    182
# 2   balance_not_updated_after_cheque_or_cash_deposit    181
# 3                      wrong_amount_of_cash_received    180
# 4                             cash_withdrawal_charge    177
# ..                                               ...    ...
# 72                               lost_or_stolen_card     82
# 73                                    card_swallowed     61
# 74                                   card_acceptance     59
# 75                          virtual_card_not_working     41
# 76                           contactless_not_working     35
#
# [77 rows x 2 columns]

# %% [markdown]
# #### PARTIE 2 - AUGMENTATION DES DONNÉES

# %%
# Trouver la catégorie majoritaire pour équilibrer
counts = train['category'].value_counts()
max_count = counts.max()

# Fonctions d'augmentation
def synonym_replacement(text, n=2):
    """Remplace aléatoirement n mots par leurs synonymes WordNet"""
    words = text.split()
    new_words = words.copy()
    random_idx = random.sample(range(len(words)), min(n, len(words)))
    for idx in random_idx:
        synonyms = wordnet.synsets(words[idx])
        if synonyms:
            lemmas = synonyms[0].lemma_names()
            if lemmas:
                new_words[idx] = lemmas[0].replace("_", " ")
    return " ".join(new_words)

def random_swap(text, n=1):
    """Échange aléatoirement l’ordre de mots"""
    words = text.split()
    for _ in range(n):
        if len(words) > 2:
            i, j = random.sample(range(len(words)), 2)
            words[i], words[j] = words[j], words[i]
    return " ".join(words)

def augment_text(text):
    """Choisit une technique d'augmentation aléatoire"""
    choice = random.choice(['synonym', 'swap', 'none'])
    if choice == 'synonym':
        return synonym_replacement(text)
    elif choice == 'swap':
        return random_swap(text)
    else:
        return text

# Générer des données augmentées pour les catégories minoritaires
augmented_rows = []
for cat, count in counts.items():
    if count < max_count:
        needed = max_count - count
        subset = train[train['category'] == cat]
        print(f"Augmentation catégorie '{cat}' ({count} → {max_count})")
        for _ in range(needed):
            original = subset.sample(1).iloc[0]
            new_text = augment_text(original['text'])
            augmented_rows.append({'text': new_text, 'category': cat})

# Fusionner et sauvegarder
augmented_df = pd.DataFrame(augmented_rows)
train_aug = pd.concat([train, augmented_df], ignore_index=True)
os.makedirs("../data/augmented", exist_ok=True)
train_aug.to_csv("../data/augmented/train_augmented.csv", index=False)

print("Nouvelle distribution après augmentation :")
print(train_aug['category'].value_counts())

# Charger dataset augmenté
train = pd.read_csv("../data/augmented/train_augmented.csv")
print("Train shape après augmentation:", train.shape)
# Out:
# [nltk_data] Downloading package wordnet to C:\Users\fatima
# [nltk_data]     ezzahra\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to C:\Users\fatima
# [nltk_data]     ezzahra\AppData\Roaming\nltk_data...
# 🔍 Distribution initiale :
# category
# card_payment_fee_charged                            187
# direct_debit_payment_not_recognised                 182
# balance_not_updated_after_cheque_or_cash_deposit    181
# wrong_amount_of_cash_received                       180
# cash_withdrawal_charge                              177
#                                                    ...
# lost_or_stolen_card                                  82
# card_swallowed                                       61
# card_acceptance                                      59
# virtual_card_not_working                             41
# contactless_not_working                              35
# Name: count, Length: 77, dtype: int64
# 📈 Augmentation de la catégorie 'direct_debit_payment_not_recognised' (182 → 187)
# 📈 Augmentation de la catégorie 'balance_not_updated_after_cheque_or_cash_deposit' (181 → 187)
# 📈 Augmentation de la catégorie 'wrong_amount_of_cash_received' (180 → 187)
# 📈 Augmentation de la catégorie 'cash_withdrawal_charge' (177 → 187)
# 📈 Augmentation de la catégorie 'transaction_charged_twice' (175 → 187)
# 📈 Augmentation de la catégorie 'declined_cash_withdrawal' (173 → 187)
# 📈 Augmentation de la catégorie 'transfer_fee_charged' (172 → 187)
# 📈 Augmentation de la catégorie 'balance_not_updated_after_bank_transfer' (171 → 187)
# 📈 Augmentation de la catégorie 'transfer_not_received_by_recipient' (171 → 187)
# 📈 Augmentation de la catégorie 'request_refund' (169 → 187)
# 📈 Augmentation de la catégorie 'card_payment_not_recognised' (168 → 187)
# 📈 Augmentation de la catégorie 'card_payment_wrong_exchange_rate' (167 → 187)
# 📈 Augmentation de la catégorie 'extra_charge_on_statement' (166 → 187)
# 📈 Augmentation de la catégorie 'wrong_exchange_rate_for_cash_withdrawal' (163 → 187)
# 📈 Augmentation de la catégorie 'Refund_not_showing_up' (162 → 187)
# 📈 Augmentation de la catégorie 'reverted_card_payment?' (161 → 187)
# 📈 Augmentation de la catégorie 'cash_withdrawal_not_recognised' (160 → 187)
# 📈 Augmentation de la catégorie 'activate_my_card' (159 → 187)
# 📈 Augmentation de la catégorie 'pending_card_payment' (159 → 187)
# 📈 Augmentation de la catégorie 'cancel_transfer' (157 → 187)
# 📈 Augmentation de la catégorie 'beneficiary_not_allowed' (156 → 187)
# 📈 Augmentation de la catégorie 'declined_card_payment' (153 → 187)
# 📈 Augmentation de la catégorie 'card_arrival' (153 → 187)
# 📈 Augmentation de la catégorie 'pending_top_up' (149 → 187)
# 📈 Augmentation de la catégorie 'pending_transfer' (148 → 187)
# 📈 Augmentation de la catégorie 'top_up_reverted' (146 → 187)
# 📈 Augmentation de la catégorie 'top_up_failed' (145 → 187)
# 📈 Augmentation de la catégorie 'pending_cash_withdrawal' (143 → 187)
# 📈 Augmentation de la catégorie 'card_linking' (139 → 187)
# 📈 Augmentation de la catégorie 'failed_transfer' (137 → 187)
# 📈 Augmentation de la catégorie 'visa_or_mastercard' (135 → 187)
# 📈 Augmentation de la catégorie 'declined_transfer' (133 → 187)
# 📈 Augmentation de la catégorie 'getting_spare_card' (129 → 187)
# 📈 Augmentation de la catégorie 'country_support' (129 → 187)
# 📈 Augmentation de la catégorie 'card_about_to_expire' (129 → 187)
# 📈 Augmentation de la catégorie 'supported_cards_and_currencies' (129 → 187)
# 📈 Augmentation de la catégorie 'transfer_timing' (128 → 187)
# 📈 Augmentation de la catégorie 'automatic_top_up' (127 → 187)
# 📈 Augmentation de la catégorie 'verify_top_up' (126 → 187)
# 📈 Augmentation de la catégorie 'apple_pay_or_google_pay' (126 → 187)
# 📈 Augmentation de la catégorie 'fiat_currency_support' (126 → 187)
# 📈 Augmentation de la catégorie 'change_pin' (122 → 187)
# 📈 Augmentation de la catégorie 'exchange_charge' (121 → 187)
# 📈 Augmentation de la catégorie 'edit_personal_details' (121 → 187)
# 📈 Augmentation de la catégorie 'why_verify_identity' (121 → 187)
# 📈 Augmentation de la catégorie 'lost_or_stolen_phone' (121 → 187)
# 📈 Augmentation de la catégorie 'disposable_card_limits' (121 → 187)
# 📈 Augmentation de la catégorie 'order_physical_card' (120 → 187)
# 📈 Augmentation de la catégorie 'exchange_via_app' (118 → 187)
# 📈 Augmentation de la catégorie 'pin_blocked' (115 → 187)
# 📈 Augmentation de la catégorie 'top_up_by_cash_or_cheque' (114 → 187)
# 📈 Augmentation de la catégorie 'top_up_by_card_charge' (114 → 187)
# 📈 Augmentation de la catégorie 'transfer_into_account' (113 → 187)
# 📈 Augmentation de la catégorie 'verify_source_of_funds' (113 → 187)
# 📈 Augmentation de la catégorie 'exchange_rate' (112 → 187)
# 📈 Augmentation de la catégorie 'card_delivery_estimate' (112 → 187)
# 📈 Augmentation de la catégorie 'card_not_working' (112 → 187)
# 📈 Augmentation de la catégorie 'top_up_by_bank_transfer_charge' (111 → 187)
# 📈 Augmentation de la catégorie 'age_limit' (110 → 187)
# 📈 Augmentation de la catégorie 'terminate_account' (108 → 187)
# 📈 Augmentation de la catégorie 'get_physical_card' (106 → 187)
# 📈 Augmentation de la catégorie 'passcode_forgotten' (105 → 187)
# 📈 Augmentation de la catégorie 'verify_my_identity' (104 → 187)
# 📈 Augmentation de la catégorie 'topping_up_by_card' (103 → 187)
# 📈 Augmentation de la catégorie 'unable_to_verify_identity' (102 → 187)
# 📈 Augmentation de la catégorie 'getting_virtual_card' (98 → 187)
# 📈 Augmentation de la catégorie 'get_disposable_virtual_card' (97 → 187)
# 📈 Augmentation de la catégorie 'top_up_limits' (97 → 187)
# 📈 Augmentation de la catégorie 'receiving_money' (95 → 187)
# 📈 Augmentation de la catégorie 'atm_support' (87 → 187)
# 📈 Augmentation de la catégorie 'compromised_card' (86 → 187)
# 📈 Augmentation de la catégorie 'lost_or_stolen_card' (82 → 187)
# 📈 Augmentation de la catégorie 'card_swallowed' (61 → 187)
# 📈 Augmentation de la catégorie 'card_acceptance' (59 → 187)
# 📈 Augmentation de la catégorie 'virtual_card_not_working' (41 → 187)
# 📈 Augmentation de la catégorie 'contactless_not_working' (35 → 187)
# ✅ Nouvelle distribution après augmentation :
# category
# card_arrival                        187
# card_linking                        187
# exchange_rate                       187
# card_payment_wrong_exchange_rate    187
# extra_charge_on_statement           187
#                                    ...
# cash_withdrawal_charge              187
# card_about_to_expire                187
# apple_pay_or_google_pay             187
# verify_my_identity                  187
# country_support                     187
# Name: count, Length: 77, dtype: int64
# 💾 Fichier sauvegardé : ../data/augmented/train_augmented.csv

# %%
train = pd.read_csv("../data/augmented/train_augmented.csv")
print("Train shape après augmentation:", train.shape)
train.head(-10)
# Out:
# Train shape après augmentation: (14399, 2)
#                                                     text  \
# 0                         I am still waiting on my card?
# 1      What can I do if my card still hasn't arrived ...
# 2      I have been waiting over a week. Is the card s...
# 3      Can I track my card while it is in the process...
# 4      How do I know if I will get my card, or if it ...
# ...                                                  ...
# 14384  Are my contactless settings but I tried to use...
# 14385                  My contactless is non-functional.
# 14386                 Can I make a contactless payments?
# 14387  How come when contactless tried to pay I at th...
# 14388                      How can I fix my contactless?
#
#                       category
# 0                 card_arrival
# 1                 card_arrival
# 2                 card_arrival
# 3                 card_arrival
# 4                 card_arrival
# ...                        ...
# 14384  contactless_not_working
# 14385  contactless_not_working
# 14386  contactless_not_working
# 14387  contactless_not_working
# 14388  contactless_not_working
#
# [14389 rows x 2 columns]

# %% [markdown]
# #### PARTIE 3 - NETTOYAGE DU TEXTE

# %%
train = pd.read_csv("../data/augmented/train_augmented.csv")
# ✅ Count number of samples per intent in the training set
print("\n🔍 Distribution of categories in TRAIN set:")
train_counts = train['category'].value_counts().reset_index()
train_counts.columns = ['category', 'Count']
print(train_counts)
# Out:
# 🔍 Distribution of categories in TRAIN set:
#                             category  Count
# 0                       card_arrival    187
# 1                       card_linking    187
# 2                      exchange_rate    187
# 3   card_payment_wrong_exchange_rate    187
# 4          extra_charge_on_statement    187
# ..                               ...    ...
# 72            cash_withdrawal_charge    187
# 73              card_about_to_expire    187
# 74           apple_pay_or_google_pay    187
# 75                verify_my_identity    187
# 76                   country_support    187
#
# [77 rows x 2 columns]

# %%
# --- NETTOYAGE COMPLET DU DATASET ---

# Calcul des métriques
lignes_texte_manquant_train = train['text'].isnull().sum()
lignes_non_texte_train = train['text'].apply(lambda x: not isinstance(x, str)).sum()
lignes_texte_trop_court_train = train['text'].apply(lambda x: isinstance(x, str) and len(x.strip()) <= 2).sum()
total_lignes_train = len(train)

# Calcul des métriques
lignes_texte_manquant_test = test['text'].isnull().sum()
lignes_non_texte_test = test['text'].apply(lambda x: not isinstance(x, str)).sum()
lignes_texte_trop_court_test = test['text'].apply(lambda x: isinstance(x, str) and len(x.strip()) <= 2).sum()
total_lignes_test = len(test)

# Affichage des résultats
print(f"RÉSULTATS POUR LE DATASET TRAIN :")
print(f"Lignes avec texte manquant (NaN) : {lignes_texte_manquant_train}")
print(f"Lignes avec non-texte : {lignes_non_texte_train}")
print(f"Lignes avec texte trop court (≤2 caractères) : {lignes_texte_trop_court_train}")
print(f"Total des lignes analysées : {total_lignes_train}")

# Affichage des résultats
print(f"RÉSULTATS POUR LE DATASET TEST :")
print(f"Lignes avec texte manquant (NaN) : {lignes_texte_manquant_test}")
print(f"Lignes avec non-texte : {lignes_non_texte_test}")
print(f"Lignes avec texte trop court (≤2 caractères) : {lignes_texte_trop_court_test}")
print(f"Total des lignes analysées : {total_lignes_test}")
# Out:
# RÉSULTATS POUR LE DATASET TRAIN :
# Lignes avec texte manquant (NaN) : 0
# Lignes avec non-texte : 0
# Lignes avec texte trop court (≤2 caractères) : 0
# Total des lignes analysées : 14399
# RÉSULTATS POUR LE DATASET TEST :
# Lignes avec texte manquant (NaN) : 0
# Lignes avec non-texte : 0
# Lignes avec texte trop court (≤2 caractères) : 0
# Total des lignes analysées : 3080

# %%
# Fonction de nettoyage
def clean_text(text):
    """
    Nettoyage simple :
    - minuscule
    - suppression ponctuation
    - suppression espaces multiples
    """
    text = text.lower()
    text = re.sub(r"[^a-z0-9\s]", "", text)
    text = re.sub(r"\s+", " ", text).strip()
    text = re.sub(r"\d+", "<NUM>", text)

    return text

# %%
# Appliquer nettoyage
train['clean_text'] = train['text'].apply(clean_text)
test['clean_text'] = test['text'].apply(clean_text)

# %%
print("Exemple après nettoyage :")
train[['text','clean_text']].head()
# Out:
# Exemple après nettoyage :
#                                                 text  \
# 0                     I am still waiting on my card?
# 1  What can I do if my card still hasn't arrived ...
# 2  I have been waiting over a week. Is the card s...
# 3  Can I track my card while it is in the process...
# 4  How do I know if I will get my card, or if it ...
#
#                                           clean_text
# 0                      i am still waiting on my card
# 1  what can i do if my card still hasnt arrived a...
# 2  i have been waiting over a week is the card st...
# 3  can i track my card while it is in the process...
# 4  how do i know if i will get my card or if it i...

# %%
# Normalisation des contractions
contractions = {
    "can't": "cannot",
    "won't": "will not",
    "i'm": "i am",
    "it's": "it is",
    "doesn't": "does not",
    "didn't": "did not",
    "hasn't": "has not",
    "haven't": "have not",
    "i've": "i have",
    "you're": "you are"
    # tu peux ajouter d'autres si nécessaire
}

def normalize_contractions(text):
    for c, full in contractions.items():
        text = text.replace(c, full)
    return text

train['clean_text'] = train['clean_text'].apply(normalize_contractions)
test['clean_text'] = test['clean_text'].apply(normalize_contractions)

print("Exemple après normalisation des contractions :")
train[['text','clean_text']].head()
# Out:
# Exemple après normalisation des contractions :
#                                                 text  \
# 0                     I am still waiting on my card?
# 1  What can I do if my card still hasn't arrived ...
# 2  I have been waiting over a week. Is the card s...
# 3  Can I track my card while it is in the process...
# 4  How do I know if I will get my card, or if it ...
#
#                                           clean_text
# 0                      i am still waiting on my card
# 1  what can i do if my card still hasnt arrived a...
# 2  i have been waiting over a week is the card st...
# 3  can i track my card while it is in the process...
# 4  how do i know if i will get my card or if it i...

# %% [markdown]
# #### PARTIE 4 - LEMMATISATION ET ANALYSE SYNTAXIQUE

# %%
nlp = spacy.load("en_core_web_sm")

def analyze_syntax(text):
    """
    Applique :
    - Tokenisation
    - Suppression des stopwords
    - Lemmatisation
    - Filtrage des caractères spéciaux
    Retourne le texte lemmatisé nettoyé.
    """
    if not isinstance(text, str):
        return ""
    
    doc = nlp(text)
    
    lemmas = [token.lemma_ for token in doc if not token.is_stop and token.is_alpha]
    
    return " ".join(lemmas)

# %%
# Appliquer sur train et test
print("Application du prétraitement syntaxique (lemmatisation)...")
train['clean_text'] = train['clean_text'].apply(analyze_syntax)
test['clean_text'] = test['clean_text'].apply(analyze_syntax)
# Out:
# 🔁 Application du prétraitement syntaxique (lemmatisation) sur TRAIN et TEST...

# %%
print("Exemple après lemmatisation :")
print(train[['text','clean_text']].head())
# Out:
# ✅ Lemmatisation et nettoyage appliqués sur la colonne 'clean_text'.
#
# Exemple (3 premières lignes du train) :
#                                                 text  \
# 0                     I am still waiting on my card?
# 1  What can I do if my card still hasn't arrived ...
# 2  I have been waiting over a week. Is the card s...
# 3  Can I track my card while it is in the process...
# 4  How do I know if I will get my card, or if it ...
#
#                     clean_text
# 0                    wait card
# 1     card not arrive NUM week
# 2          wait week card come
# 3  track card process delivery
# 4               know card lose

# %%
# Sauvegarder les datasets prétraités
train.to_csv("../data/processed/train_preprocessed.csv", index=False)
test.to_csv("../data/processed/test_preprocessed.csv", index=False)

print("Données prétraitées sauvegardées dans '../data/processed/'")
# Out:
# 💾 Données nettoyées et analysées syntaxiquement sauvegardées dans data/processed/

# %%
train = pd.read_csv("../data/processed/train_preprocessed.csv")
test = pd.read_csv("../data/processed/test_preprocessed.csv")

# Afficher un aperçu des données nettoyées et analysées
# Affiche les colonnes clean_text et syntax pour voir le résultat
print("✅ Aperçu des 5 premières lignes :")
train.head()
# Out:
# ✅ Aperçu des 5 premières lignes :
#                                                 text      category  \
# 0                     I am still waiting on my card?  card_arrival
# 1  What can I do if my card still hasn't arrived ...  card_arrival
# 2  I have been waiting over a week. Is the card s...  card_arrival
# 3  Can I track my card while it is in the process...  card_arrival
# 4  How do I know if I will get my card, or if it ...  card_arrival
#
#                     clean_text
# 0                    wait card
# 1     card not arrive NUM week
# 2          wait week card come
# 3  track card process delivery
# 4               know card lose
